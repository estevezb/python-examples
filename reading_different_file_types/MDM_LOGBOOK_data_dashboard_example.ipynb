# %%
import pandas as pd

import numpy as np

import itables 

import panel as pn

import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
tp_data =pd.read_excel(r"C:\Users\beste\OneDrive - Qral Group\01 Narcan\08 Mastering\00 Logbook\Customer Mastering LogBook v1.43.xlsx", sheet_name='AccountMaster')

itables.show(tp_data)
# Out:
# <div class="itables">
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables { font-size: medium; }
#
# .itables select, .itables input {
#     color: inherit;
# }
# </style>
# <table id="itables_bbbb30b3_c26a_4cf4_a03d_90b20c29012c" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>Source</th>
#       <th>Q_ID</th>
#       <th>Transaction Bucket</th>
#       <th>ShipTo</th>
#       <th>Address</th>
#       <th>City</th>
#       <th>State</th>
#       <th>Zip</th>
#       <th>Max of Date</th>
#       <th>Sum of Quantity</th>
#       <th>Count of Records</th>
#       <th>ShipTo Code</th>
#       <th>MDM ID</th>
#       <th>MDM Dup</th>
#       <th>MDM First Flag</th>
#       <th>Qualifier</th>
#       <th>x</th>
#       <th>Final - Status</th>
#       <th>Final MDM ID</th>
#       <th>Final SFDC ID</th>
#       <th>Flag: manually added new MDM ID</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody>
#
# </table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     $(document).ready(function () {
#         document.querySelectorAll("#itables_bbbb30b3_c26a_4cf4_a03d_90b20c29012c:not(.dataTable)").forEach(table => {
#             // Define the table data
#             const data = [["Diamond", "Diamond | NMSM | SAN MIGUEL CO DETENTION CENTER | 26 NM 283 | LAS VEGAS | NM | 87701", "Specialty Distributor", "SAN MIGUEL CO DETENTION CENTER", "26 NM 283", "LAS VEGAS", "NM", "87701", "2021-05-14 00:00:00", 16.0, 4.0, "NMSM", "EMUSHCO0000001", "NaN", 1, true, "x", "Found", "EMUSHCO0000001", "0014x00000EC1TtAAL", NaN], ["CommonCents", "CommonCents | Montville Police Department | Montville Police Department | 911 Norwich-New London Turnpike | Montville | CT | 06382", "Specialty Distributor", "Montville Police Department", "911 Norwich-New London Turnpike", "Montville", "CT", "06382", "2023-07-13 00:00:00", 82.0, 82.0, "Montville Police Department", "EMUSHCO0000002", "Duplicate", 1, true, "x", "Found", "EMUSHCO0000002", "0014x00000EC0szAAD", NaN], ["CommonCents", "CommonCents | Montville Police Department | Montville Police Department | 911 Norwich-New London Turnpike | Montville | CT | 06382", "Specialty Distributor", "Montville Police Department", "911 Norwich-New London Turnpike", "Montville", "CT", "6382", "2023-07-13 00:00:00", 82.0, 82.0, "Montville Police Department", "EMUSHCO0000002", "Duplicate", 2, false, "x", "Found", "EMUSHCO0000002", "0014x00000EC0szAAD", NaN], ["Chargeback", "Chargeback | - | IRONWOOD STATE PRISON PHARMACY | 19005 WILEYS WELL RD | BLYTHE | CA | 92225", "Specialty Distributor", "IRONWOOD STATE PRISON PHARMACY", "19005 WILEYS WELL RD", "BLYTHE", "CA", "92225", "2022-10-06 00:00:00", 161.0, 4.0, "-", "EMUSHCO0000003", "Duplicate", 1, true, "x", "Found", "EMUSHCO0000003", "0014x00000EC4HCAA1", NaN], ["ExFactory", "ExFactory | AXE06001 | Ironwood State Prison | 19005 Wileys Well Road | Blythe | CA | 92225", "Direct to Customer", "Ironwood State Prison", "19005 Wileys Well Road", "Blythe", "CA", "92225-", "2023-10-04 00:00:00", 3144.0, 15.0, "AXE06001", "EMUSHCO0020892", "NaN", 1, true, "x", "Found", "EMUSHCO0000003", "0014x00000EC4HCAA1", NaN], ["ExFactory", "ExFactory | AXE06001 | Ironwood State Prison | 19005 Wileys Well Road | Blythe | CA | 92225", "NaN", "Ironwood State Prison", "19005 Wileys Well Road", "Blythe", "CA", "92225", "NaN", NaN, NaN, "AXE06001", "EMUSHCO0000003", "Duplicate", 2, false, "x", "Found", "EMUSHCO0000003", "0014x00000EC4HCAA1", NaN], ["Chargeback", "Chargeback | - | HAMILTON COUNTY HEALTH DEPARTMENT | 921 EAST THIRD STREET | CHATTANOOGA | TN | 37403", "Specialty Distributor", "HAMILTON COUNTY HEALTH DEPARTMENT", "921 EAST THIRD STREET", "CHATTANOOGA", "TN", "37403", "2023-08-11 00:00:00", 416.0, 4.0, "-", "EMUSHCO0000004", "NaN", 1, true, "x", "Found", "EMUSHCO0000004", "0014x00001ucPGDAA2", NaN], ["ExFactory", "ExFactory | AX10249 | HAMILTON COUNTY | ATTN CAMILLA BIBBS LEE | CHATTANOOGA | TN | 37403", "Sales to Wholesaler", "HAMILTON COUNTY", "ATTN CAMILLA BIBBS LEE", "CHATTANOOGA", "TN", "37403", "2017-11-28 00:00:00", 300.0, 1.0, "AX10249", "EMUSHCO0027992", "Duplicate", 1, true, "x", "Found", "EMUSHCO0000004", "0014x00001ucPGDAA2", NaN], ["Truax", "Truax | - | SHERIDAN CTY,DISTRICT #3 | 1008 WATER STREET | CLEARMONT | WY | 82835", "Specialty Distributor", "SHERIDAN CTY,DISTRICT #3", "1008 WATER STREET", "CLEARMONT", "WY", "82835", "2022-10-11 14:47:00", 1.0, 1.0, "-", "EMUSHCO0000005", "NaN", 1, true, "x", "Found", "EMUSHCO0000005", "0014x00001RU967AAD", NaN], ["Chargeback", "Chargeback | - | POTTAWATOMIE COUNTY PUBLIC SAFETY | 14209 HIGHWAY 177 | SHAWNEE | OK | 74804", "Specialty Distributor", "POTTAWATOMIE COUNTY PUBLIC SAFETY", "14209 HIGHWAY 177", "SHAWNEE", "OK", "74804", "2023-01-17 00:00:00", 2.0, 1.0, "-", "EMUSHCO0000006", "NaN", 1, true, "x", "Found", "EMUSHCO0000006", "0014x00001hUPJMAA4", NaN], ["ExFactory", "ExFactory | AXE19650 | Pottawatomie County Public Safety Center | 14209 highway 177 | Shawnee | OK | 74804", "Direct to Customer", "Pottawatomie County Public Safety Center", "14209 highway 177", "Shawnee", "OK", "74804", "2022-11-16 00:00:00", 120.0, 1.0, "AXE19650", "EMUSHCO0030976", "NaN", 1, true, "x", "Found",  ...

# %%
# Load the Panel extension
pn.extension()


# Create a DataFrame widget
df_widget = pn.widgets.DataFrame(tp_data, name='Trade Partner Data',  width=1200)



# Create a Panel with the DataFrame widget
dashboard = pn.Column("# MDM LogBook Dashboard", df_widget)


# Create a dropdown widget
columns = list(tp_data.columns)
dropdown = pn.widgets.Select(name='Select column', options=columns)

# Create a plot and wrap it in a HoloViews pane
plot = tp_data.hvplot.scatter(y=columns[0])
plot_pane = pn.pane.HoloViews(plot,  width=800, height=600)


# Update the plot when the dropdown value changes
def update_plot(event):
    tp_data['Final SFDC ID'] = tp_data['Final SFDC ID'].astype(str)
    tp_data['Final MDM ID'] = tp_data['Final MDM ID'].astype(str)
    plot = tp_data.hvplot.line(y=dropdown.value)
    plot_pane.object = plot

dropdown.param.watch(update_plot, 'value')

# Create a second dropdown widget
dropdown2 = pn.widgets.Select(name='Select column for second plot', options=columns)

# Create a second plot and wrap it in a HoloViews pane
plot2 = tp_data.hvplot.scatter(y=columns[0])
plot_pane2 = pn.pane.HoloViews(plot2, width=800, height=600)

# Update the second plot when the second dropdown value changes
def update_plot2(event):
    tp_data['Final SFDC ID'] = tp_data['Final SFDC ID'].astype(str)
    tp_data['Final MDM ID'] = tp_data['Final MDM ID'].astype(str)
    plot2 = tp_data.hvplot.line(y=dropdown2.value)
    plot_pane2.object = plot2

dropdown2.param.watch(update_plot2, 'value')

# Add the second dropdown and plot to the dashboard
dashboard = pn.Column("# MDM LogBook Dashboard", dropdown, df_widget, plot_pane, dropdown2, plot_pane2)

# Display the dashboard in the notebook
dashboard




###=======================================================other dashboard vieweing and sharing options


# dashboard.servable() panel creates a Bokeh application from your Panel object that can be served by a Bokeh server 
# This allows you to share your dashboard as a web app that can be accessed from a browser
# serving a Panel app requires a running Python serve
# dashboard.servable()
#For full interactivity, you can serve the dashboard as a standalone app 
#requires a running Python server
# dashboard.show()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'0ab7ec48-9e26-40e0-87d8-4e7534768892': {'version…
